# %% [markdown]
# # SpERI for HFIR Cycle 502

# %% [markdown]
# ***
# ## Basic constants and functions
# ***

# %%
import numpy as np
import sympy as sym
import scipy as sc
import matplotlib.pyplot as plt
import mcstasscript as ms
import scienceplots
import time, math, os
from scipy.optimize import curve_fit
from scipy.signal import hilbert,convolve,find_peaks,savgol_filter
from scipy.fft import fft,fftfreq,ifft
from scipy.integrate import quad,simpson
from scipy.interpolate import CubicSpline
from matplotlib.animation import FuncAnimation, PillowWriter
from itertools import islice

plt.style.use(['science', 'notebook', 'grid', 'default', 'bright'])
plot_height = 8
plot_width = plot_height*1.618

np.set_printoptions(suppress=True)

SMALL_SIZE,MEDIUM_SIZE,BIGGER_SIZE = 10,15,20
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rc('axes', titlesize=BIGGER_SIZE)    # actually gets title font size (glitch in matplotlib?)
plt.rcParams.update({'axes.grid':True})

plt.rc('text', usetex=False)
if False: #Additions to latex preamble for matplotlib:
    plt.rc('text', usetex=True)
    plt.rc('text.latex', preamble=r'\usepackage{amsmath,amsthm,amssymb,amsfonts,braket,siunitx}')
    plt.rcParams["font.family"] = "Computer Modern Roman"
sym.init_printing()

G = -1.832471e8    #gyromagnetic ratio of neutron (rad/T/m^2)
M = 1.674927e-27    #mass of neutron (kg)
HBAR = 1.054571e-34    #plancks constant (kg m^2/s)
CL = G/(HBAR*2*np.pi)*M*1e-10    #Larmor phase constant (T^-1 m^-1 AA^-1)
print(f'Larmor constant = {round(CL,3)}')
# Out:
# Larmor constant = -46320.933

# %%
def rebin(data,new_shape):
    """Rebins 2D data by taking average."""
    sh = new_shape[0],data.shape[0]//new_shape[0],new_shape[1],data.shape[1]//new_shape[1]
    return data.reshape(sh).mean(3).mean(1)

def get_SS_focus(harm,Ls,res,ml,a,L):
    """Returns SESANS magnetic field focuing condtion (T)."""
    return 2*np.pi*harm*Ls/(res/1e3)/(CL*lam*a*(L[1] - L[0]))

def cos(x,amp,freq,phase,shim):
    """Simple cosine with shim."""
    return amp*np.cos(x*freq + phase) + shim

def pol_sc(x,A,B,freq):
    """Linear combination of sine and cosine."""
    return A*np.cos(x*freq) + B*np.sin(x*freq)

def quad_cos(x,amp,freq,qfreq,phase,shim):
    """Cosine with quadratic frequency and shim."""
    return amp*np.cos(x*freq + x**2*qfreq + phase) + shim

def g_cos(x,amp,freq,phase,shim,mean,sigma):
    """Cosine with Gaussian envelope and shim."""
    return amp*np.exp(-(x - mean)**2/2/sigma**2)*np.cos(x*freq + phase) + shim

def quad(x,a,b,c):
    """Returns quadratic for peak fitting."""
    return a*x**2 + b*x + c

def sample_factor(x,r,ls,ld):
    """Returns tupule of sample seen by pixel x."""
    return -r/2 - (1 -ls/ld)*x, r/2 - (1 -ls/ld)*x

#mask options (mm):
#slit_width,slit_height,slit_num,slit_offset = 1.,10.,11,.5 #1 mm Al-B mask
#slit_inner,slit_outer = 22.,40.
#slit_width,slit_height,slit_num,slit_offset = 4.,30.,3,0. #4 mm B-plastic mask
#slit_inner,slit_outer = 20.,40.
#slit_width,slit_height,slit_num,slit_offset = 2.,10.,5,1. #2 mm B-plastic mask
#slit_inner,slit_outer = 20.,40.

# %%
def my_cos(x,amp,freq,phase):
    return amp*np.cos(freq*(x-.5)+phase)

def get_fit(pols,cg_cs_fine,ini_guess=[.1,210,-4],\
             plot=True,indxs=(50,55),p_sen=.5):
    """Reuturns the polarization fitted from phase scan."""
    fitted = []
    fig = plt.figure(figsize=(8,6))
    phase = ini_guess[-1]  #intial phase guess
    for indx in range(len(pols[0,:])):
        points = pols[:,indx]
        lb,ub = (0,ini_guess[1]-5,phase-p_sen),(1,ini_guess[1]+5,phase+p_sen)  #continuity of fitted phase

        guess=[np.max(points),ini_guess[1],phase]
        parms,_ = curve_fit(my_cos,cg_cs,points,p0=guess,bounds=(lb,ub))
        fitted.append(parms)

        if indxs[0] < indx < indxs[1]:
            plt.plot(cg_cs,points,'o',color=f'C{indx%8}',label=f'{indx}')
            plt.plot(cg_cs_fine,my_cos(cg_cs_fine,*parms),color=f'C{indx%8}')
            if plot: print(f'amp,freq,phase = {np.round(parms,3)}')
        phase = parms[-1]  #continuity of fitted phase

    plt.legend()
    plt.grid()
    if plot: plt.show()
    else: plt.close()
    
    return np.array(fitted)

def trad(empty,sample,plot=True):
    """Returns traditional radiograph."""
    trad1 = np.sum(empty,axis=0)
    trad2 = np.sum(sample,axis=0)
    if plot:
        fig = plt.figure(figsize=(8,4))
        plt.title('Traditional radiograph')
        plt.plot(trad1,label='empty')
        plt.plot(trad2,label='sample')
        plt.legend()
        plt.grid()
        plt.show()
    return trad2/trad1  #normalized radiograph

def barber(e,s,title,cg_cs,vmin=-1,vmax=1):
    """Makes barber plot of the phase scan."""
    fig,ax = plt.subplots(1,2,figsize=(11,4))
    fig.suptitle(f'{title}')
    im1 = ax[0].imshow(e,origin='lower',vmin=vmin,vmax=vmax,aspect='auto',interpolation='bilinear')
    ax[0].set_title('Empty')
    ax[0].yaxis.set_ticks(range(9))
    ax[0].yaxis.set_ticklabels(cg_cs)
    im2 = ax[1].imshow(s,origin='lower',vmin=vmin,vmax=vmax,aspect='auto',interpolation='bilinear')
    ax[1].set_title('Sample')
    ax[1].yaxis.set_ticks(range(9))
    ax[1].yaxis.set_ticklabels(cg_cs)
    plt.colorbar(im1)
    plt.colorbar(im2)
    plt.show()
    
def triptych(trad,dark,phase,rng=(30,100)):
    """Plots dark field,phase,and trad."""
    plt.plot(trad[rng[0]:rng[-1]],label='Trad')
    plt.plot(dark[rng[0]:rng[-1]],label='Dark')
    plt.plot(phase[rng[0]:rng[-1]],label='Phase')
    plt.legend()
    plt.grid()
    plt.show()

def compare(e,s,plot_freq=False,plot_norm=False,plot_diff=True):
    """Plots the fitted parameters of blank and sample."""
    fig,ax = plt.subplots(1,2,figsize=(12,5))
    ax[0].set_title('Pol envelope')
    ax[0].plot(e[:,0],label='empty')
    ax[0].plot(s[:,0],label='sample')
    dark = s[:,0]/e[:,0]
    if plot_norm: ax[0].plot(dark,label='Normed')
    ax[0].set_ylim((0,1))  #should be polarization...
    ax[0].legend()
    ax[0].grid()
    ax[1].set_title('Fitted phase')
    ax[1].plot(e[:,2],label='empty')
    ax[1].plot(s[:,2],label='sample')
    phase = s[:,2]-e[:,2]
    if plot_diff: ax[1].plot(phase,label='Diff')
    ax[1].legend()
    ax[1].grid()
    plt.show()
    if plot_freq:
        fig = plt.figure(figsize=(8,6))
        plt.title('Fitted frequency')
        plt.plot(e[:,1],label='empty')
        plt.plot(s[:,1],label='sample')
        plt.legend()
        plt.grid()
        plt.show()
    return dark,phase

# %% [markdown]
# ### Algebraic SEMSANS solutions

# %%
I1,I2,I3,I4,x,phi,theta,delta1,delta2 = sym.symbols('I_1,I_2,I_3,I_4,x,phi,theta,delta_1,delta_2', real=True)
L1,L2,L3,L4,a,b,lam,delta = sym.symbols('L_1,L_2,L_3,L_4,a,b,lambda,delta', real=True, positive=True)
larm = sym.symbols('c_L', real=True, negative=True)
#b=a  #idealized case

A = 5e-3 #in Tesla
B = 5e-3 #in Tesla

def MWP(a,b,I,x,phi,inv=False):
    """Field integral from MWP."""
    if inv: b = -b
    return I*(a*x + b*x*phi)

def AER(L1,L2,I1,I2,focus_SS=False):
    """Field integral with option focusing conditions."""
    result = MWP(a,b,I1,x-L1*phi,phi) + MWP(a,b,I2,x-L2*phi,phi)
    if focus_SS: result = result.subs(I2,-I1)
    return result.expand().collect([a,b]).simplify() 

print('Ideal:')
display(AER(L1,L2,I1,I2,focus_SS=True))

print('First MWP off:')
display(AER(L1,L2,I1+delta1,I2))
display(AER(L1,L2,I1+delta1,I2,focus_SS=True))

print('Second MWP off:')
display(AER(L1,L2,I1,I2+delta2))
display(AER(L1,L2,I1,I2+delta2,focus_SS=True))

print('Both MWPs off:')
display(AER(L1,L2,I1+delta1,I2+delta2))
display(AER(L1,L2,I1+delta1,I2+delta2,focus_SS=True))

# %%
theta = sym.symbols('theta', real=True)
b=a  #idealized case
def double_AER(L1,L2,L3,L4,I1,I2,I3,I4,focus_SS=False):
    """Field integral with option focusing conditions."""
    result = MWP(a,b,I1,x-L1*phi,phi) + MWP(a,b,I2,x-L2*phi,phi) + \
                MWP(a,b,I3,x-L3*phi,phi) + MWP(a,b,I4,x-L4*phi,phi)
    if focus_SS: result = result.subs([(I2,I1),(I3,-I1),(I4,-I1)])
    return result.expand().collect([a,b]).simplify() 

def SEMSANS_tilt(L1,L2,I1,I2,focus_SS=False):
    """Field integral with option focusing conditions."""
    result = MWP(a,b,I1,x*(sym.cos(theta)-phi*sym.sin(theta))-L1*phi,phi) + \
                MWP(a,b,I2,x*(sym.cos(theta)-phi*sym.sin(theta))-L2*phi,phi)
    if focus_SS: result = result.subs(I2,-I1*L1/L2)
    return result.expand().collect([a,b]).simplify() 

#print('Double AER:')
#display(double_AER(L1,L2,L3,L4,I1,I2,I3,I4,focus_SS=True))
#print('Unfocused SEMSANS:')
#display(SEMSANS_tilt(L1,L2,I1,I2,focus_SS=False))

print('Theta:')
display(SEMSANS_tilt(L1,L2,I1,I2,focus_SS=True))
theta = 0
print(f'Theta={theta}:')
display(SEMSANS_tilt(L1,L2,I1,I2,focus_SS=True))
theta = sym.pi/4
print(f'Theta={theta}:')
display(SEMSANS_tilt(L1,L2,I1,I2,focus_SS=True))
theta = -sym.pi/4
print(f'Theta={theta}:')
display(SEMSANS_tilt(L1,L2,I1,I2,focus_SS=True))

# %%
theta = sym.symbols('theta', real=True)
b=a  #idealized case
def tri_SEMSANS_tilt(L1,L2,I1,I2,focus_SS=False):
    """Field integral with option focusing conditions."""
    result = MWP(a,b,I1,x*(sym.cos(theta)-phi*sym.sin(theta))-L1*phi,phi) + \
                MWP(a,b,I2,x*(sym.cos(theta)-phi*sym.sin(theta))-L2*phi,phi,inv=True)
    if focus_SS: result = result.subs(I2,I1*L1/L2)
    return result.expand().collect([a,b]).simplify()

print('Theta:')
display(tri_SEMSANS_tilt(L1,L2,I1,I2,focus_SS=True))
#theta = 0
#print(f'Theta={theta}:')
#display(tri_SEMSANS_tilt(L1,L2,I1,I2,focus_SS=False))

# %% [markdown]
# ***
# ## Building the beamline
# ***

# %%
lam = 5.5  #wavelength (AA)
dl = lam*.25/100
ap_width = 20. #aperature dimensions (mm)
ap_height = 40.

strength = 2.7e-3 #T per amp, experimental
cg_gpa = strength*1e4  #gauss per amp for center guide field
MWP_parm = {'FI0':0.,'a':strength*2,'b':strength*2,'c':0.0,'d':0.0}
MWP_dim = {'x':.02,'y':.02,'z':.1}
CG_dim = {'x':.02,'y':.02,'z':.3}
LG_parm = {'B0':0.0,'Bx':0.0,'By':0.0,'Bz':0.0}

MWP_sep,Ld = .4, 3. #beamline parameters (m)
Ls = .8  #sample to detector
Lss = Ld - Ls  #source to sample
Lc = .6  #collimator length
dists = {'pol':.0,'slit':Lc,'P1':1.17,'CG':1.27,'P2':1.57,'ana':1.8,'sam':Lss,'det':Ld}
assert math.isclose(dists['P2'] - dists['P1'], MWP_sep,rel_tol=1e-2), 'Prisms too far apart!'
L = np.array([Ld-dists['P1']-MWP_dim['z']/2,Ld-dists['P2']-MWP_dim['z']/2])
L1, L2 = L  #naming the distances

#resolution grating parameters
res_slit_width,res_slit_height,res_slit_num,res_slit_offset = 1.,10.,11,.5
res_slit_inner,res_slit_outer = 22.,40.
res_slit_width = 1.
res = Ls/(Ld-Lc)*res_slit_width #geometric resolution (mm)

#sample grating parameters
slit_width,slit_height,slit_num,slit_offset = 1.,10.,11,.5 #1 mm Al-B mask
slit_inner,slit_outer = 22.,40.

print(f'Wavelength: {lam} p/m  {round(dl,3)} (Angstroms)')
print(f'Aperture diameter: {ap_width} (mm)')
print(f'Resolution slit width: {res_slit_width} (mm)')
print(f'Midpoint distances from MWP to detector: {np.round(L,3)} (m)')
print(f'Distance from aperture to detector: {np.round(Ld,3)} (m)')
print(f'Distance from sample to detector: {np.round(Ls,3)} (m)')
print(f'Geometric resolution: {round(res, 3)} (mm) \n')

harms = np.linspace(0,1,10)
c1 = get_SS_focus(harms,Ls,res,lam,MWP_parm['a'],L)
c2 = -c1
c_CG = 0.
print(f'MWP currents: {np.round(c1,3)} (amps)')

fig, ax1 = plt.subplots(1, 1, figsize=(plot_width,plot_height))
ax1.plot(c1[1:],res/harms[1:],'.',ms=15,label='SPERI')
ax1.axhline(y=res, label='R_GEO',linewidth=3,color='C1')
ax1.axhline(y=2*res_slit_width, label='Slit sep',linewidth=3,color='C2')
ax1.axhline(y=res_slit_width, label='Slit size',linewidth=3,color='C3')
ax1.set(ylabel='Resolution (mm)')
ax1.set(xlabel='Current (A)')
ax1.legend()
plt.tight_layout()
plt.show()

per_rad = abs(2*np.pi/(CL*lam*MWP_parm['a']*(c1[1:]*L1 + c2[1:]*L2)))
per_lin = np.round([res/i for i in harms[1:]],3)

pol_dir = [1,0,0] #direction of polarizer (x,y,z)
pol_dir = [i/np.sqrt(sum([j**2 for j in pol_dir])) for i in pol_dir]

det_res_Anger = 116.0/512.0 #Anger camera bin size (mm/pixel)
det_res_tpix = .1 #Anger camera bin size (mm/pixel)
det_x,det_y = 10,10
#bin_x,bin_y,bin_ang = int(det_x/det_res_Anger),int(det_y/det_res_Anger),100
bin_x,bin_y,bin_ang = 128,128,128
print(f'Detector size: {[round(i,3) for i in [det_x,det_y]]} (mm)')
print(f'[x,y] bin number: {[round(i,3) for i in [bin_x,bin_y]]}')
print(f'[x,y] bin size: {[round(i,3) for i in [det_x/bin_x,det_y/bin_y]]} (mm) \n')

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(plot_width,plot_height/1.5))
ax1.plot(harms[1:],per_rad*180/np.pi,'.',ms=15)
ax1.set(ylabel='Angular period (deg)')
ax2.plot(harms[1:],per_lin,'.',ms=15)
ax2.axhline(y=2*det_x/bin_x, label='McStas Nyquist',color='C1')
ax2.axhline(y=2*det_res_Anger, label='Anger Nyquist',color='C2')
ax2.set(ylabel='Linear period (mm)')
ax2.legend()
fig.supxlabel("Harmonic")
plt.tight_layout()
plt.show()

sam_ang,sam_offset = [0.,0.,0.],[0.,0.] #angular and linear offset (degs and mm)

div1_file = "\"acc_source.dat\""
div2_file = "\"acc_sample.dat\""
div2b_file = "\"acc_post_sample.dat\""
div3_file = "\"acc_det.dat\""
twoD_file = "\"AER_2D.dat\""

max_div = (det_x + ap_width)*1e-3/Ld/2*180/np.pi
print(f'Maximum divergence angle (deg): {round(max_div,5)}')

print("-"*80)     #Start of instrument definition
SPERI = ms.McStas_instr('SPERI_HFIR_2023', author = 'Sam McKay', origin = 'Indiana University')
delta_lambda = SPERI.add_parameter("double", "delta_lambda", value = dl, comment="Wavelength spread [AA]")
low_count = SPERI.add_parameter("int", "low_count", value = 0, comment="if true flips analyzer direction [N/A]")
all_off = SPERI.add_parameter("int", "all_off", value = 0, comment="if true turns off all MWPs [N/A]")
cur1 = SPERI.add_parameter("double", "cur1", value = c1[0], comment="MWP1 current [Amps]")
cur2 = SPERI.add_parameter("double", "cur2", value = c2[0], comment="MWP2 current [Amps]")
BCG = SPERI.add_parameter("double", "BCG", value = c_CG, comment="Center guide field [Gauss]")
polx = SPERI.add_parameter("double", "polx", value = pol_dir[0], comment="x-component of polarizer [N/A]")
poly = SPERI.add_parameter("double", "poly", value = pol_dir[1], comment="y-component of polarizer [N/A]")
polz = SPERI.add_parameter("double", "polz", value = pol_dir[2], comment="z-component of polarizer [N/A]")
SPERI.show_parameters()

print("-"*80)    #Source and polarizer (collimation included via source parameters):
SPERI.add_component("origin","Progress_bar")
SPERI.add_component("arm","Arm", AT=[0,0,0], RELATIVE="origin")

src = SPERI.add_component("src","Source_sam", AT=[0,0,0], RELATIVE="origin")
src.set_parameters(xwidth=ap_width*1e-3,yheight=ap_height*1e-3,I1=1e12,lambda0=lam,dlambda="delta_lambda",\
                   focus_xw=det_x/1e3,focus_yh=det_y/1e3,dist=Ld)
print(src)

div1 = SPERI.add_component("div1","DivPos_monitor", AT=[0,0,1e-6], RELATIVE="origin")
div1.set_parameters(xwidth=det_x*1e-3,yheight=det_y*1e-3,nb=bin_x,ndiv=bin_ang, \
                   filename=div1_file,maxdiv=max_div,vertical=0)
print(div1)

pol = SPERI.add_component("pol","Set_pol", AT=[0,0,2e-6], RELATIVE="origin")
pol.set_parameters(px="polx", py="poly", pz="polz")
print(pol)

slit = SPERI.add_component("slit","grating_mask", AT=[0,0,Lc], RELATIVE="origin")
slit.set_parameters(outer=1e-3*res_slit_outer,inner=1e-3*res_slit_inner,Tr_len=1e-3*res_slit_width,\
                    Ab_len=1e-3*res_slit_width,offset=1e-3*res_slit_offset,slits=res_slit_num)
print(slit)

print("-"*80)    #Magnetic Wollaston prisms:
MWP1 = SPERI.add_component("MWP1","Pol_MWP_v3", AT=[0,0,dists['P1']], RELATIVE="origin")
MWP1.set_parameters(xwidth=MWP_dim['x'], yheight=MWP_dim['y'], zdepth=MWP_dim['z'], \
                    current="cur1*(1-all_off)", a=MWP_parm['a'], b=MWP_parm['b'])
print(MWP1)

CG = SPERI.add_component("CG","Pol_constBfield", AT=[0,0,dists['CG']], RELATIVE="origin")
CG.set_parameters(xwidth=CG_dim['x'], yheight=CG_dim['y'], zdepth=CG_dim['z'], \
                    B="BCG*(1-all_off)")
print(CG)

MWP2 = SPERI.add_component("MWP2","Pol_MWP_v3", AT=[0,0,dists['P2']], RELATIVE="origin")
MWP2.set_parameters(xwidth=MWP_dim['x'], yheight=MWP_dim['y'], zdepth=MWP_dim['z'], \
                    current="cur2*(1-all_off)", a=MWP_parm['a'], b=MWP_parm['b'])
print(MWP2)

print("-"*80)    #Analyzer and slit pattern (sample):
ana = SPERI.add_component("ana","PolAnalyser_ideal", AT=[0,0,dists['ana']], RELATIVE="origin")
ana.set_parameters(mx="polx*(1-2*low_count)", my="poly*(1-2*low_count)", mz="polz*(1-2*low_count)")
print(ana)

div2 = SPERI.add_component("div2","DivPos_monitor", AT=[0,0,Lss-1e-6], RELATIVE="origin")
div2.set_parameters(xwidth=det_x*1e-3,yheight=det_y*1e-3,nb=bin_x,ndiv=bin_ang, \
                   filename=div2_file,maxdiv=max_div,vertical=0)
print(div2)

sam = SPERI.add_component("sam","grating_mask", AT=[sam_offset[0]*1e-3,sam_offset[1]*1e-3,Lss], RELATIVE="origin")
sam.set_parameters(outer=1e-3*slit_outer,inner=1e-3*slit_inner,Tr_len=1e-3*slit_width,Ab_len=1e-3*slit_width,\
                   offset=1e-3*slit_offset,slits=slit_num)
sam.set_ROTATED([sam_ang[0],sam_ang[1],sam_ang[2]])
print(sam)

div2b = SPERI.add_component("div2b","DivPos_monitor", AT=[0,0,Lss+1e-6], RELATIVE="origin")
div2b.set_parameters(xwidth=det_x*1e-3,yheight=det_y*1e-3,nb=bin_x,ndiv=bin_ang, \
                   filename=div2b_file,maxdiv=max_div,vertical=0)
print(div2b)

div3 = SPERI.add_component("div3","DivPos_monitor", AT=[0,0,Ld-1e-6], RELATIVE="origin")
div3.set_parameters(xwidth=det_x*1e-3,yheight=det_y*1e-3,nb=bin_x,ndiv=bin_ang, \
                   filename=div3_file,maxdiv=max_div,vertical=0)
print(div3)

print("-"*80)    #2D detector
det = SPERI.add_component("det","PSD_monitor", AT=[0,0,Ld], RELATIVE="origin")
det.set_parameters(nx=bin_x,ny=bin_y,filename=twoD_file,xwidth=det_x*1e-3,yheight=det_y*1e-3)
print(det)

print("-"*80)    #Final instrument summary:
SPERI.show_components()
# Out:
# Wavelength: 5.5 p/m  0.014 (Angstroms)
# Aperture diameter: 20.0 (mm)
# Resolution slit width: 1.0 (mm)
# Midpoint distances from MWP to detector: [1.78 1.38] (m)
# Distance from aperture to detector: 3.0 (m)
# Distance from sample to detector: 0.8 (m)
# Geometric resolution: 0.333 (mm)
#
# MWP currents: [ 0.     3.045  6.09   9.134 12.179 15.224 18.269 21.313 24.358 27.403] (amps)
# Detector size: [10, 10] (mm)
# [x,y] bin number: [128, 128]
# [x,y] bin size: [0.078, 0.078] (mm)
# Maximum divergence angle (deg): 0.28648
# --------------------------------------------------------------------------------
# double delta_lambda  = 0.01375  // Wavelength spread [AA]
# int    low_count     = 0        // if true flips analyzer direction [N/A]
# int    all_off       = 0        // if true turns off all MWPs [N/A]
# double cur1          = 0.0      // MWP1 current [Amps]
# double cur2          = -0.0     // MWP2 current [Amps]
# double BCG           = 0.0      // Center guide field [Gauss]
# double polx          = 1.0      // x-component of polarizer [N/A]
# double poly          = 0.0      // y-component of polarizer [N/A]
# double polz          = 0.0      // z-component of polarizer [N/A]
# --------------------------------------------------------------------------------
# COMPONENT src = Source_sam
#   dist = 3.0 [m]
#   focus_xw = 0.01 [m]
#   focus_yh = 0.01 [m]
#   lambda0 = 5.5 [AA]
#   dlambda = delta_lambda [AA]
#   I1 = 1000000000000.0 [1/(cm**2*sr)]
#   yheight = 0.04 [m]
#   xwidth = 0.02 [m]
# AT [0, 0, 0] RELATIVE origin
# COMPONENT div1 = DivPos_monitor
#   nb = 128 [1]
#   ndiv = 128 [1]
#   filename = "acc_source.dat" [string]
#   xwidth = 0.01 [m]
#   yheight = 0.01 [m]
#   maxdiv = 0.2864788975654116 [degrees]
#   vertical = 0 [1]
# AT [0, 0, 1e-06] RELATIVE origin
# COMPONENT pol = Set_pol
#   px = polx [1]
#   py = poly [1]
#   pz = polz [1]
# AT [0, 0, 2e-06] RELATIVE origin
# COMPONENT slit = grating_mask
#   outer = 0.04 [m]
#   inner = 0.022 [m]
#   Tr_len = 0.001 [m]
#   Ab_len = 0.001 [m]
#   offset = 0.0005 [m]
#   slits = 11 [N/A]
# AT [0, 0, 0.6] RELATIVE origin
# --------------------------------------------------------------------------------
# COMPONENT MWP1 = Pol_MWP_v3
#   xwidth = 0.02 [m]
#   yheight = 0.02 [m]
#   zdepth = 0.1 [m]
#   current = cur1*(1-all_off) [A]
#   a = 0.0054 [T/amp]
#   b = 0.0054 [T/rad/amp]
# AT [0, 0, 1.17] RELATIVE origin
# COMPONENT CG = Pol_constBfield
#   xwidth = 0.02 [m]
#   yheight = 0.02 [m]
#   zdepth = 0.3 [m]
#   B = BCG*(1-all_off) [Gauss]
# AT [0, 0, 1.27] RELATIVE origin
# COMPONENT MWP2 = Pol_MWP_v3
#   xwidth = 0.02 [m]
#   yheight = 0.02 [m]
#   zdepth = 0.1 [m]
#   current = cur2*(1-all_off) [A]
#   a = 0.0054 [T/amp]
#   b = 0.0054 [T/rad/amp]
# AT [0, 0, 1.57] RELATIVE origin
# --------------------------------------------------------------------------------
# COMPONENT ana = PolAnalyser_ideal
#   mx = polx*(1-2*low_count) [1]
#   my = poly*(1-2*low_count) [1]
#   mz = polz*(1-2*low_count) [1]
# AT [0, 0, 1.8] RELATIVE origin
# COMPONENT div2 = DivPos_monitor
#   nb = 128 [1]
#   ndiv = 128 [1]
#   filename = "acc_sample.dat" [string]
#   xwidth = 0.01 [m]
#   yheight = 0.01 [m]
#   maxdiv = 0.2864788975654116 [degrees]
#   vertical = 0 [1]
# AT [0, 0, 2.199999] RELATIVE origin
# COMPONENT sam = grating_mask
#   outer = 0.04 [m]
#   inner = 0.022 [m]
#   Tr_len = 0.001 [m]
#   Ab_len = 0.001 [m]
#   offset = 0.0005 [m]
#   slits = 11 [N/A]
# AT [0.0, 0.0, 2.2] RELATIVE origin
# ROTATED [0.0, 0.0, 0.0] RELATIVE origin
# COMPONENT div2b = DivPos_monitor
#   nb = 128 [1]
#   ndiv = 128 [1]
#   filename = "acc_post_sample.dat" [string]
#   xwidth = 0.01 [m]
#   yheight = 0.01 [m]
#   maxdiv = 0.2864788975654116 [degrees]
#   vertical = 0 [1]
# AT [0, 0, 2.2000010000000003] RELATIVE origin
# COMPONENT div3 = DivPos_monitor
#   nb = 128 [1]
#   ndiv = 128 [1]
#   filename = "acc_det.dat" [string]
#   xwidth = 0.01 [m]
#   yheight = 0.01 [m]
#   maxdiv = 0.2864788975654116 [degrees]
#   vertical = 0 [1]
# AT [0, 0, 2.999999] RELATIVE origin
# --------------------------------------------------------------------------------
# COMPONENT det = PSD_monitor
#   nx = 128 [1]
#   ny = 128 [1]
#   filename = "AER_2D.dat" [string]
#   xwidth = 0.01 [m]
#   yheight = 0.01 [m]
# AT [0, 0, 3.0] RELATIVE origin
# --------------------------------------------------------------------------------
# origin Progress_bar      AT      (0, 0, 0)                  ABSOLUTE
# arm    Arm               AT      (0, 0, 0)                  RELATIVE origin
# src    Source_sam        AT      (0, 0, 0)                  RELATIVE origin
# div1   DivPos_monitor    AT      (0, 0, 1e-06)              RELATIVE origin
# pol    Set_pol           AT      (0, 0, 2e-06)              RELATIVE origin
# slit   grating_mask      AT      (0, 0, 0.6)                RELATIVE origin
# MWP1   Pol_MWP_v3        AT      (0, 0, 1.17)               RELATIVE origin
# CG     Pol_constBfield   AT      (0, 0, 1.27)               RELATIVE origin
# MWP2   Pol_MWP_v3        AT      (0, 0, 1.57)               RELATIVE origin
# ana    PolAnalyser_ideal AT      (0, 0, 1.8)                RELATIVE origin
# div2   DivPos_monitor    AT      (0, 0, 2.199999)           RELATIVE origin
# sam    grating_mask      AT      (0.0, 0.0, 2.2)            RELATIVE origin
#                          ROTATED (0.0, 0.0, 0.0)            RELATIVE origin
# div2b  DivPos_monitor    AT      (0, 0, 2.2000010000000003) RELATIVE origin
# div3   DivPos_monitor    AT      (0, 0, 2.999999)           RELATIVE origin
# det    PSD_monitor       AT      (0, 0, 3.0)                RELATIVE origin

# %% [markdown]
# ### Portion of grating seen by beam:

# %%
def grating(x,a,t,n,o):
    """Returns 1D transmission function of grating mask."""
    max_x = x[-1]
    result = np.zeros(len(x))
    for indx,i in enumerate(x):
        for s in range(1,n+1):
            if (i > (max_x - o - (a + t)*(s - 1) - t) and i < (max_x - o - (a + t)*(s - 1))):
                result[indx] = 1
    return result

def seen_grating(x,grating,xd,ls,ld,res):
    """Returns the grating as seen by point xd on the detector."""
    lower = -res/2 + (1 - ls/ld)*xd
    upper = res/2 + (1 - ls/ld)*xd
    print(f'Lower/upper limits: {round(lower,3)},{round(upper,3)}')
    mask = [i if (lower<x[indx] and x[indx]<upper) else 0 for indx,i in enumerate(grating)]
    return mask, upper, lower

x_fine = np.linspace(-slit_inner/2,slit_inner/2,400,endpoint=True)
MASK = grating(x_fine,slit_width,slit_width,slit_num,slit_offset)
SEEN,UPPER,LOWER = seen_grating(x_fine,MASK,0,Ls,Ld,Ls*ap_width/Ld)

print(f'Ls={round(Ls,2)}, Ld={round(Ld,2)}, SF={round(1-Ls/Ld,2)} R={round(res,2)} (mm)')
fig = plt.figure(figsize=(plot_width,plot_height/2))
plt.plot(x_fine,MASK,'--',label='Grating',color='black',linewidth=1)
plt.plot(x_fine,SEEN,linewidth=4,label=f'x_d=0')
xd = [det_x/2]
for x in xd:
    SEEN_xd,UPPER_xd,LOWER_xd = seen_grating(x_fine,MASK,x,Ls,Ld,Ls*ap_width/Ld) 
    plt.plot(x_fine,SEEN_xd,'--',linewidth=3,label=f'x_d={x}')
plt.xlabel('x (mm)')
plt.legend()
plt.show()
# Out:
# Lower/upper limits: -3.279,3.279
# Ls=0.8, Ld=2.44, SF=0.67 R=0.43 (mm)
# Lower/upper limits: 0.082,6.639

# %% [markdown]
# ***
# ## Simulation scans
# ***

# %%
def do_run(ray_num,MWP1_current,MWP2_current,CG_current,sample_in=True,pols=True,plot=True,get_divs=False):
    """Performs McStas simulation of high and low count spin state.
    Returns high and low count intensities."""
    result = []
    if sample_in: sam.set_AT([sam_offset[0]*1e-3,sam_offset[1]*1e-3,Lss])
    else: sam.set_AT([1+sam_offset[0]*1e-3,sam_offset[1]*1e-3,Lss]) #one meter offset
    BCG.value = CG_current*cg_gpa  #center guide field strength (Gauss)
    SPERI.settings(output_path=f'{path}hc_{round(MWP1_current,2)}_{round(CG_current,3)}_{round(MWP2_current,2)}',\
                 ncount=ray_num)
    low_count.value, all_off.value, cur1.value, cur2.value = 0, 0, MWP1_current, MWP2_current
    AER_hc = SPERI.backengine()
    if plot: ms.make_plot(AER_hc,fontsize=5)
    if pols==False or int(MWP1_current*10)==0: #ignores low counts
        result.append(AER_hc[-1].Intensity)
    else:
        SPERI.settings(output_path=f'{path}lc_{round(MWP1_current,2)}_{round(CG_current,3)}_{round(MWP2_current,2)}',\
                     ncount=ray_num)
        low_count.value, all_off.value, cur1.value, cur2.value = 1, 0, MWP1_current, MWP2_current
        AER_lc = SPERI.backengine()
        if plot: ms.make_plot(AER_lc,fontsize=5)
        result.extend([AER_hc[-1].Intensity,AER_lc[-1].Intensity])
    if get_divs:
        result.extend([det.Intensity for det in AER_hc[:-1]]) #includes acceptance detectors
    return result

def do_scan(ray_num,curs1,curs2,curscg,sample_in=True,pols=True,plot=True,\
            cg=False,daisy=False,full=False):
    """Performs current scans of MWP1, CG, and/or MWP2 for given number of currents.
    Returns lists of intensities from each do_run."""
    results = []
    if daisy:
        for c in curs1:
            results.extend(do_run(ray_num,c,-c,curscg,sample_in=sample_in,pols=pols,plot=plot))   
    if cg:
        for c in curscg:
            BCG.value = c*cg_gpa
            results.extend(do_run(ray_num,curs1,curs2,c,sample_in=sample_in,pols=pols,plot=plot))
        BCG.value = 0. #return center guide field to zero
    if full:
        for c1 in curs1:
            for cg in curscg:
                results.extend(do_run(ray_num,c1,-c1,cg,sample_in=sample_in,pols=pols,plot=plot))
    return results

# %% [markdown]
# ### 1mm sample grating and blank phase scan

# %%
RAYS = 5e6 #global variables
do_sam,do_empt = True,True

#cgs = np.insert(np.linspace(.5,.53,9),0,0)
cgs = np.linspace(.5,.53,9)
curs = c1[1:3]

print(f'MWP currents: {np.round(curs,3)}')
print(f'Phase currents: {np.round(cgs,3)}')

if do_sam:
    path = 'Simulations\\SPERI\\1mm_sample\\'
    time_start = time.time()
    sample_scan = do_scan(RAYS,curs,-curs,cgs,sample_in=True,full=True,pols=True,plot=False)
    time_end = time.time()
    print(f'Sim time: {round((time_end-time_start)/60,3)} minutes.')

if do_empt:
    path = 'Simulations\\SPERI\\empty\\'
    time_start = time.time()
    empty_scan = do_scan(RAYS,curs,-curs,cgs,sample_in=False,full=True,pols=True,plot=False)
    time_end = time.time()
    print(f'Sim time: {round((time_end-time_start)/60,3)} minutes.')
# Out:
# MWP currents: [3.045 6.09 ]
# Phase currents: [0.5   0.504 0.508 0.511 0.515 0.519 0.522 0.526 0.53 ]
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.5_-3.04"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.5_-3.04
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305553 div1_ERR=386.497 div1_N=624999 "acc_source.dat"
# Detector: div2_I=341647 div2_ERR=354.11 div2_N=1.39222e+006 "acc_sample.dat"
# Detector: div2b_I=168379 div2b_ERR=247.871 div2b_N=697724 "acc_post_sample.dat"
# Detector: div3_I=191069 div3_ERR=265.133 div3_N=773258 "acc_det.dat"
# Detector: det_I=191069 det_ERR=265.133 det_N=773258 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.5_-3.04]. Time: 4 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.5_-3.04"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.5_-3.04
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305501 div1_ERR=386.465 div1_N=624893 "acc_source.dat"
# Detector: div2_I=338449 div2_ERR=351.917 div2_N=1.39244e+006 "acc_sample.dat"
# Detector: div2b_I=171917 div2b_ERR=251.468 div2b_N=696139 "acc_post_sample.dat"
# Detector: div3_I=186190 div3_ERR=260.753 div3_N=771847 "acc_det.dat"
# Detector: det_I=186190 det_ERR=260.753 det_N=771847 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.5_-3.04]. Time: 4 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.504_-3.04"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.504_-3.04
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305693 div1_ERR=386.586 div1_N=625286 "acc_source.dat"
# Detector: div2_I=342374 div2_ERR=354.447 div2_N=1.39303e+006 "acc_sample.dat"
# Detector: div2b_I=168549 div2b_ERR=247.812 div2b_N=697667 "acc_post_sample.dat"
# Detector: div3_I=191762 div3_ERR=265.571 div3_N=773463 "acc_det.dat"
# Detector: det_I=191762 det_ERR=265.571 det_N=773463 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.504_-3.04]. Time: 4 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.504_-3.04"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.504_-3.04
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305160 div1_ERR=386.249 div1_N=624195 "acc_source.dat"
# Detector: div2_I=337876 div2_ERR=351.518 div2_N=1.39114e+006 "acc_sample.dat"
# Detector: div2b_I=172105 div2b_ERR=251.435 div2b_N=696777 "acc_post_sample.dat"
# Detector: div3_I=186102 div3_ERR=260.405 div3_N=773451 "acc_det.dat"
# Detector: det_I=186102 det_ERR=260.405 det_N=773451 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.504_-3.04]. Time: 4 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.508_-3.04"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.508_-3.04
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305201 div1_ERR=386.275 div1_N=624279 "acc_source.dat"
# Detector: div2_I=341841 div2_ERR=354.281 div2_N=1.39283e+006 "acc_sample.dat"
# Detector: div2b_I=169653 div2b_ERR=249.214 div2b_N=697295 "acc_post_sample.dat"
# Detector: div3_I=190648 div3_ERR=264.734 div3_N=773008 "acc_det.dat"
# Detector: det_I=190648 det_ERR=264.734 det_N=773008 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.508_-3.04]. Time: 4 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.508_-3.04"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.508_-3.04
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305498 div1_ERR=386.462 div1_N=624886 "acc_source.dat"
# Detector: div2_I=338882 div2_ERR=352.366 div2_N=1.39133e+006 "acc_sample.dat"
# Detector: div2b_I=171272 div2b_ERR=250.921 div2b_N=696628 "acc_post_sample.dat"
# Detector: div3_I=187403 div3_ERR=261.824 div3_N=772417 "acc_det.dat"
# Detector: det_I=187403 det_ERR=261.824 det_N=772417 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.508_-3.04]. Time: 4 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.511_-3.04"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.511_-3.04
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=306385 div1_ERR=387.024 div1_N=626702 "acc_source.dat"
# Detector: div2_I=340346 div2_ERR=353.348 div2_N=1.39231e+006 "acc_sample.dat"
# Detector: div2b_I=171308 div2b_ERR=251.003 div2b_N=697984 "acc_post_sample.dat"
# Detector: div3_I=188562 div3_ERR=262.978 div3_N=773216 "acc_det.dat"
# Detector: det_I=188562 det_ERR=262.978 det_N=773217 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.511_-3.04]. Time: 4 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.511_-3.04"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.511_-3.04
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305758 div1_ERR=386.627 div1_N=625418 "acc_source.dat"
# Detector: div2_I=340259 div2_ERR=353.325 div2_N=1.39238e+006 "acc_sample.dat"
# Detector: div2b_I=169790 div2b_ERR=249.536 div2b_N=697904 "acc_post_sample.dat"
# Detector: div3_I=189532 div3_ERR=263.862 div3_N=773647 "acc_det.dat"
# Detector: det_I=189532 det_ERR=263.862 det_N=773647 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.511_-3.04]. Time: 4 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.515_-3.04"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.515_-3.04
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305297 div1_ERR=386.335 div1_N=624475 "acc_source.dat"
# Detector: div2_I=338639 div2_ERR=352.117 div2_N=1.39036e+006 "acc_sample.dat"
# Detector: div2b_I=171906 div2b_ERR=251.532 div2b_N=694654 "acc_post_sample.dat"
# Detector: div3_I=186266 div3_ERR=260.88 div3_N=770167 "acc_det.dat"
# Detector: det_I=186266 det_ERR=260.88 det_N=770167 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.515_-3.04]. Time: 4 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.515_-3.04"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.515_-3.04
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305203 div1_ERR=386.276 div1_N=624284 "acc_source.dat"
# Detector: div2_I=341742 div2_ERR=354.244 div2_N=1.38995e+006 "acc_sample.dat"
# Detector: div2b_I=168435 div2b_ERR=248.028 div2b_N=695982 "acc_post_sample.dat"
# Detector: div3_I=191169 div3_ERR=265.322 div3_N=771962 "acc_det.dat"
# Detector: det_I=191169 det_ERR=265.322 det_N=771962 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.515_-3.04]. Time: 5 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.519_-3.04"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.519_-3.04
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305329 div1_ERR=386.356 div1_N=624541 "acc_source.dat"
# Detector: div2_I=338808 div2_ERR=352.061 div2_N=1.39277e+006 "acc_sample.dat"
# Detector: div2b_I=172554 div2b_ERR=251.895 div2b_N=696792 "acc_post_sample.dat"
# Detector: div3_I=186432 div3_ERR=260.786 div3_N=772946 "acc_det.dat"
# Detector: det_I=186433 det_ERR=260.786 det_N=772947 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.519_-3.04]. Time: 4 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.519_-3.04"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.519_-3.04
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305403 div1_ERR=386.403 div1_N=624693 "acc_source.dat"
# Detector: div2_I=342129 div2_ERR=354.394 div2_N=1.39164e+006 "acc_sample.dat"
# Detector: div2b_I=168529 div2b_ERR=247.823 div2b_N=697554 "acc_post_sample.dat"
# Detector: div3_I=191573 div3_ERR=265.46 div3_N=773143 "acc_det.dat"
# Detector: det_I=191573 det_ERR=265.46 det_N=773143 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.519_-3.04]. Time: 5 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.522_-3.04"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.522_-3.04
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305281 div1_ERR=386.326 div1_N=624444 "acc_source.dat"
# Detector: div2_I=339075 div2_ERR=352.413 div2_N=1.39219e+006 "acc_sample.dat"
# Detector: div2b_I=171300 div2b_ERR=250.831 div2b_N=696871 "acc_post_sample.dat"
# Detector: div3_I=187185 div3_ERR=261.52 div3_N=772600 "acc_det.dat"
# Detector: det_I=187185 det_ERR=261.52 det_N=772600 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.522_-3.04]. Time: 4 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.522_-3.04"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.522_-3.04
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=304910 div1_ERR=386.091 div1_N=623685 "acc_source.dat"
# Detector: div2_I=341259 div2_ERR=353.99 div2_N=1.39096e+006 "acc_sample.dat"
# Detector: div2b_I=169038 div2b_ERR=248.762 div2b_N=695943 "acc_post_sample.dat"
# Detector: div3_I=190131 div3_ERR=264.425 div3_N=771499 "acc_det.dat"
# Detector: det_I=190131 det_ERR=264.425 det_N=771499 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.522_-3.04]. Time: 4 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.526_-3.04"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.526_-3.04
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305553 div1_ERR=386.498 div1_N=625000 "acc_source.dat"
# Detector: div2_I=339751 div2_ERR=352.982 div2_N=1.39101e+006 "acc_sample.dat"
# Detector: div2b_I=169401 div2b_ERR=249.169 div2b_N=696050 "acc_post_sample.dat"
# Detector: div3_I=188765 div3_ERR=263.169 div3_N=771675 "acc_det.dat"
# Detector: det_I=188765 det_ERR=263.169 det_N=771675 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.526_-3.04]. Time: 4 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.526_-3.04"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.526_-3.04
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305698 div1_ERR=386.589 div1_N=625296 "acc_source.dat"
# Detector: div2_I=339910 div2_ERR=353.106 div2_N=1.39141e+006 "acc_sample.dat"
# Detector: div2b_I=170926 div2b_ERR=250.753 div2b_N=696554 "acc_post_sample.dat"
# Detector: div3_I=188422 div3_ERR=262.929 div3_N=772142 "acc_det.dat"
# Detector: det_I=188422 det_ERR=262.929 det_N=772142 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.526_-3.04]. Time: 5 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.53_-3.04"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.53_-3.04
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305339 div1_ERR=386.362 div1_N=624561 "acc_source.dat"
# Detector: div2_I=341470 div2_ERR=354.043 div2_N=1.39192e+006 "acc_sample.dat"
# Detector: div2b_I=168550 div2b_ERR=248.153 div2b_N=696847 "acc_post_sample.dat"
# Detector: div3_I=191068 div3_ERR=265.244 div3_N=772370 "acc_det.dat"
# Detector: det_I=191068 det_ERR=265.244 det_N=772370 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_3.04_0.53_-3.04]. Time: 4 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.53_-3.04"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.53_-3.04
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=304401 div1_ERR=385.768 div1_N=622643 "acc_source.dat"
# Detector: div2_I=338913 div2_ERR=352.33 div2_N=1.3912e+006 "acc_sample.dat"
# Detector: div2b_I=172238 div2b_ERR=251.826 div2b_N=696430 "acc_post_sample.dat"
# Detector: div3_I=186804 div3_ERR=261.313 div3_N=772918 "acc_det.dat"
# Detector: det_I=186804 det_ERR=261.313 det_N=772918 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_3.04_0.53_-3.04]. Time: 4 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_6.09_0.5_-6.09"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_6.09_0.5_-6.09
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305397 div1_ERR=386.399 div1_N=624681 "acc_source.dat"
# Detector: div2_I=340063 div2_ERR=353.713 div2_N=1.38912e+006 "acc_sample.dat"
# Detector: div2b_I=170353 div2b_ERR=250.154 div2b_N=694480 "acc_post_sample.dat"
# Detector: div3_I=188493 div3_ERR=262.626 div3_N=770263 "acc_det.dat"
# Detector: det_I=188493 det_ERR=262.626 det_N=770263 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_6.09_0.5_-6.09]. Time: 4 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_6.09_0.5_-6.09"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_6.09_0.5_-6.09
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305560 div1_ERR=386.502 div1_N=625014 "acc_source.dat"
# Detector: div2_I=338999 div2_ERR=352.946 div2_N=1.38968e+006 "acc_sample.dat"
# Detector: div2b_I=169330 div2b_ERR=249.051 div2b_N=695851 "acc_post_sample.dat"
# Detector: div3_I=188131 div3_ERR=262.2 div3_N=771615 "acc_det.dat"
# Detector: det_I=188131 det_ERR=262.2 det_N=771615 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_6.09_0.5_-6.09]. Time: 5 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_6.09_0.504_-6.09"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_6.09_0.504_-6.09
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305100 div1_ERR=386.211 div1_N=624072 "acc_source.dat"
# Detector: div2_I=341254 div2_ERR=354.712 div2_N=1.39249e+006 "acc_sample.dat"
# Detector: div2b_I=171309 div2b_ERR=250.943 div2b_N=696245 "acc_post_sample.dat"
# Detector: div3_I=189565 div3_ERR=263.254 div3_N=771961 "acc_det.dat"
# Detector: det_I=189565 det_ERR=263.254 det_N=771961 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_6.09_0.504_-6.09]. Time: 4 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_6.09_0.504_-6.09"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_6.09_0.504_-6.09
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305731 div1_ERR=386.61 div1_N=625364 "acc_source.dat"
# Detector: div2_I=338865 div2_ERR=353.204 div2_N=1.39046e+006 "acc_sample.dat"
# Detector: div2b_I=169299 div2b_ERR=248.904 div2b_N=697362 "acc_post_sample.dat"
# Detector: div3_I=188202 div3_ERR=261.914 div3_N=773215 "acc_det.dat"
# Detector: det_I=188202 det_ERR=261.914 det_N=773215 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\lc_6.09_0.504_-6.09]. Time: 4 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_6.09_0.508_-6.09"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\1mm_sample\hc_6.09_0.508_-6.09
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=306013 div1_ERR=386.789 div1_N=625941 "acc_source.dat"
# Detector: div2_I=341032 div2_ERR=353.146 div2_N=1.39341e+006 "acc_sample.dat"
# Detector: div2b_I=171105 div2b_ERR=250.531 div2b_N=697842 "acc_post_sample.dat"
# ...
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\hc_6.09_0.519_-6.09
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=306363 div1_ERR=387.009 div1_N=626656 "acc_source.dat"
# Detector: div2_I=339220 div2_ERR=353.438 div2_N=1.39119e+006 "acc_sample.dat"
# Detector: div2b_I=339222 div2b_ERR=353.439 div2b_N=1.3912e+006 "acc_post_sample.dat"
# Detector: div3_I=384923 div3_ERR=376.5 div3_N=1.5623e+006 "acc_det.dat"
# Detector: det_I=384923 det_ERR=376.5 det_N=1.5623e+006 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\hc_6.09_0.519_-6.09]. Time: 4 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\lc_6.09_0.519_-6.09"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\lc_6.09_0.519_-6.09
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=306044 div1_ERR=386.808 div1_N=626003 "acc_source.dat"
# Detector: div2_I=340815 div2_ERR=354.526 div2_N=1.39159e+006 "acc_sample.dat"
# Detector: div2b_I=340815 div2b_ERR=354.526 div2b_N=1.39159e+006 "acc_post_sample.dat"
# Detector: div3_I=378879 div3_ERR=372.511 div3_N=1.56314e+006 "acc_det.dat"
# Detector: det_I=378879 det_ERR=372.511 det_N=1.56314e+006 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\lc_6.09_0.519_-6.09]. Time: 5 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\hc_6.09_0.522_-6.09"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\hc_6.09_0.522_-6.09
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=306155 div1_ERR=386.878 div1_N=626231 "acc_source.dat"
# Detector: div2_I=339691 div2_ERR=352.424 div2_N=1.3922e+006 "acc_sample.dat"
# Detector: div2b_I=339691 div2b_ERR=352.424 div2b_N=1.3922e+006 "acc_post_sample.dat"
# Detector: div3_I=383480 div3_ERR=375.079 div3_N=1.56304e+006 "acc_det.dat"
# Detector: det_I=383480 det_ERR=375.079 det_N=1.56304e+006 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\hc_6.09_0.522_-6.09]. Time: 4 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\lc_6.09_0.522_-6.09"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\lc_6.09_0.522_-6.09
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=306142 div1_ERR=386.87 div1_N=626205 "acc_source.dat"
# Detector: div2_I=340431 div2_ERR=352.905 div2_N=1.39153e+006 "acc_sample.dat"
# Detector: div2b_I=340431 div2b_ERR=352.905 div2b_N=1.39153e+006 "acc_post_sample.dat"
# Detector: div3_I=379909 div3_ERR=372.704 div3_N=1.56212e+006 "acc_det.dat"
# Detector: det_I=379909 det_ERR=372.704 det_N=1.56212e+006 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\lc_6.09_0.522_-6.09]. Time: 5 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\hc_6.09_0.526_-6.09"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\hc_6.09_0.526_-6.09
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305674 div1_ERR=386.574 div1_N=625247 "acc_source.dat"
# Detector: div2_I=340451 div2_ERR=352.452 div2_N=1.39199e+006 "acc_sample.dat"
# Detector: div2b_I=340451 div2b_ERR=352.452 div2b_N=1.39199e+006 "acc_post_sample.dat"
# Detector: div3_I=381300 div3_ERR=373.516 div3_N=1.56235e+006 "acc_det.dat"
# Detector: det_I=381300 det_ERR=373.516 det_N=1.56235e+006 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\hc_6.09_0.526_-6.09]. Time: 5 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\lc_6.09_0.526_-6.09"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\lc_6.09_0.526_-6.09
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305521 div1_ERR=386.477 div1_N=624934 "acc_source.dat"
# Detector: div2_I=340112 div2_ERR=352.151 div2_N=1.39188e+006 "acc_sample.dat"
# Detector: div2b_I=340112 div2b_ERR=352.151 div2b_N=1.39188e+006 "acc_post_sample.dat"
# Detector: div3_I=382635 div3_ERR=374.325 div3_N=1.56266e+006 "acc_det.dat"
# Detector: det_I=382635 det_ERR=374.325 det_N=1.56266e+006 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\lc_6.09_0.526_-6.09]. Time: 4 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\hc_6.09_0.53_-6.09"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\hc_6.09_0.53_-6.09
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305335 div1_ERR=386.36 div1_N=624554 "acc_source.dat"
# Detector: div2_I=340458 div2_ERR=353.832 div2_N=1.38994e+006 "acc_sample.dat"
# Detector: div2b_I=340458 div2b_ERR=353.833 div2b_N=1.38995e+006 "acc_post_sample.dat"
# Detector: div3_I=379145 div3_ERR=372.565 div3_N=1.56172e+006 "acc_det.dat"
# Detector: det_I=379145 det_ERR=372.566 det_N=1.56172e+006 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\hc_6.09_0.53_-6.09]. Time: 4 [s]
# loading system configuration
#
# INFO: Using directory: "C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\lc_6.09_0.53_-6.09"
# INFO: Regenerating c-file: SPERI_HFIR_2023.c
# Info:    'Source_sam' is a contributed component.
# Info:    'grating_mask' is a contributed component.
# Info:    'Pol_MWP_v3' is a contributed component.
# CFLAGS=
# INFO: Recompiling: SPERI_HFIR_2023.exe
# SPERI_HFIR_2023.c: In function 'mcuse_dir':
# SPERI_HFIR_2023.c:3419:8: warning: implicit declaration of function 'mkdir' [-Wimplicit-function-declaration]
#      if(mkdir(dirname, 0777)) {
#         ^~~~~
# SPERI_HFIR_2023.c: In function 'sighandler':
# SPERI_HFIR_2023.c:5325:64: warning: implicit declaration of function 'getpid'; did you mean 'gets_s'? [-Wimplicit-function-declaration]
#    printf("\n# " MCCODE_STRING ": [pid %i] Signal %i detected", getpid(), sig);
#                                                                 ^~~~~~
#                                                                 gets_s
# INFO: ===
# INFO: Placing instr file copy SPERI_HFIR_2023.instr in dataset C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\lc_6.09_0.53_-6.09
#
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# [SPERI_HFIR_2023] Initialize
# INFO: Set_pol(pol): Setting polarization to (1.000000, 0.000000, 0.000000)
# *** TRACE end ***
#
# Save [SPERI_HFIR_2023]
# Detector: div1_I=305209 div1_ERR=386.28 div1_N=624296 "acc_source.dat"
# Detector: div2_I=339933 div2_ERR=353.368 div2_N=1.39194e+006 "acc_sample.dat"
# Detector: div2b_I=339933 div2b_ERR=353.368 div2b_N=1.39194e+006 "acc_post_sample.dat"
# Detector: div3_I=384861 div3_ERR=376.258 div3_N=1.56266e+006 "acc_det.dat"
# Detector: det_I=384861 det_ERR=376.258 det_N=1.56266e+006 "AER_2D.dat"
#
# Finally [SPERI_HFIR_2023: C:\Users\samck\Documents\GitHub\AER-HFIR-2023\Simulations\SPERI\empty\lc_6.09_0.53_-6.09]. Time: 5 [s]
# loading system configuration
#
# Sim time: 5.51 minutes.

# %% [markdown]
# ## Scan Analysis:

# %%
def show_image(im,vmax=None,vmin=None,norm=False):
    """Quick single-image plot."""
    if norm: im=im/np.max(im)
    plt.imshow(im)
    plt.imshow(im,origin='lower')#,vmax=vmax,vmin=vmin)
    plt.colorbar()
    plt.show()
    
def plot_graphs(graphs,sep=False):
    """Quick 1D plot."""
    for g in graphs:
        plt.plot(g)
        if sep: plt.show()
    plt.grid()
    plt.show()

def get_ixy(counts):
    """Returns marginals from list of intensities."""
    for c in counts:
        ix.append(np.mean(c,axis=0))
        iy.append(np.mean(c,axis=1))
    return np.array(ix),np.array(iy)

def get_pols(hcs,lcs):
    """Returns polarization from high and low counts."""
    assert len(hcs)==len(lcs), "hc length must equal lc length"
    result,px,py = [],[],[]
    for (hc,lc) in zip(hcs,lcs):
        result = (hc-lc)/(hc+lc)
        px.append(np.mean(result,axis=0))
        py.append(np.mean(result,axis=1))
    return np.array(result),np.array(px),np.array(py)

#si,six,siy = get_ints(rs_sample_scan[0,:],rs_sample_scan[1,:])
sp,spx,spy = get_pols(sample_scan[0::2],sample_scan[1::2])
ep,epx,epy = get_pols(empty_scan[0:2*len(cgs):2],empty_scan[1:2*len(cgs):2])

print(np.shape(spx))

for indx,i in enumerate(spx):
    plt.plot(i,label=f'{indx}')
plt.legend()
plt.show()
for i in epx:
    plt.plot(i)
plt.show()

#rs_empty_scan = np.reshape(empty_scan,(2,len(cgs),len(curs),128,128))  #reshape for numpy slicing
#ei,eix,eiy = get_ints(rs_empty_scan[0,:,:,:,:],rs_empty_scan[1,:,:,:,:])
#ep,epx,epy = get_pols(rs_empty_scan[0,:,:,:,:],rs_empty_scan[1,:,:,:,:])

#print(np.shape(spx))
#barber(epx[:,0,:],spx[:,0,:],'MWP 1 amp',np.round(cgs,3),vmin=-.1,vmax=.1)
#trad1 = trad(eix,six)
# Out:
# (18, 128)

# %% [markdown]
# ***
# ## Data Analysis
# ***

# %% [markdown]
# ### Data Loader

# %%
def data_loader(dirs,plot=False,N0=True):
    """Loads data into tuple of titles and 2D intensities in curscan format."""
    data,counts,curs = [],[],[]
    titles = [],[]
    for d in islice(os.walk(dirs),1,None):
        MWP_crnts = d[0].split('\\')[-1].split('_')[1]
        prefix = d[0].split('\\')[-1][:2]
        counts.append(prefix)
        curs.append(float(MWP_crnts))
        data.append(ms.load_data(d[0])[-1].Intensity)
    output = sorted(zip(curs,counts,data)) #sorts by prefix (hc or lc), then MWP current
    titles = [k[1]+str(k[0]) for k in output]
    output_data = [k[2] for k in output]
    return titles,output_data

# %%
#path = 'C:\\Users\\xsm\\Documents\\GitHub\\AER-HFIR-1-23\\Simulations\\'
path = 'C:\\Users\\samck\\Documents\\GitHub\\AER-HFIR-2023\\Simulations\\'
sim_folder = 'exp_444_daisy\\'

ts,cur_scan = data_loader(path+sim_folder)
currents = []
for indx,i in enumerate(ts):
    currents.append(float(i[2:]))
currents = sorted(list(set(currents)))  #removes duplicate currents
print(f'Loaded currents: \n {currents}')
print(f'Total = {len(currents)}')

# %%
empty_currents = currents

# %%
path = 'C:\\Users\\samck\\Documents\\GitHub\\AER-HFIR-2023\\Simulations\\'
sim_folder = 'exp_444_daisy_empty\\'

ts,empty_cur_scan = data_loader(path+sim_folder)
empty_currents = []
for indx,i in enumerate(ts):
    empty_currents.append(float(i[2:]))
empty_currents = sorted(list(set(empty_currents)))  #removes duplicate currents
print(f'Loaded currents: \n {empty_currents}')
print(f'Total = {len(empty_currents)}')

# %% [markdown]
# ***
# ### Polarization Extraction
# ***

# %%
def get_pol(h,l):
    """Returns 2D polarization from current scans."""
    pol = np.zeros(np.shape(h))
    for indx,val in np.ndenumerate(pol):
        psum = h[indx[0],indx[1]] + l[indx[0],indx[1]]
        if psum != 0:
            pol[indx[0],indx[1]] = (h[indx[0],indx[1]] - l[indx[0],indx[1]])/psum
    return pol

process_empties = True
ignore_first = True
do_rebin = False

if ignore_first:
    highs = np.array(cur_scan[1::2]) #removes zero-current scan
    lows = np.array(cur_scan[2::2])
    pols = [get_pol(highs[i],lows[i]) for i in range(0,(len(cur_scan)-1)//2)]
    pol_labels = np.round(currents[1:],2)
else:
    highs = np.array(cur_scan[::2]) #includes zeroth scan in polarizations
    lows = np.array(cur_scan[1::2])
    pols = [get_pol(highs[i],lows[i]) for i in range(0,len(cur_scan)//2)]
    pol_labels = np.round(currents,2)
if process_empties:
    if ignore_first:
        empty_highs = np.array(empty_cur_scan[1::2])
        empty_lows = np.array(empty_cur_scan[2::2])
        empty_pols = [get_pol(empty_highs[i],empty_lows[i]) for i in range(0,(len(empty_cur_scan)-1)//2)]
    else:
        empty_highs = np.array(empty_cur_scan[::2])
        empty_lows = np.array(empty_cur_scan[1::2])
        empty_pols = [get_pol(empty_highs[i],empty_lows[i]) for i in range(0,len(empty_cur_scan)//2)]

if do_rebin:
    rebin_size = (50,50)
    print(f'New bin size: {round(det_x/rebin_size[0],3)} (mm)')

print(f'Currents used: {np.round(currents,2)} \n')

plot_pols,plot_all_slices,plot_slices = False,False,True
if plot_pols:
    for indx,p in enumerate(pols):
        fig = plt.figure(figsize=(plot_width,plot_height))
        plt.title(f'Harm. {indx+1}, {pol_labels[indx]} amps')
        plt.tight_layout()
        if do_rebin: p=rebin(p,rebin_size)
        plt.imshow(p,origin='lower',extent=[-det_x/2,det_x/2,-det_y/2,det_y/2],interpolation='none')
        plt.ylabel('y (mm)')
        plt.xlabel('x (mm)')
        plt.colorbar()
        plt.show()
if plot_all_slices:
    fig = plt.figure(figsize=(plot_width,plot_height))
    x = np.linspace(-det_x/2,det_x/2,bin_x)
    for indx,p in enumerate(pols):
        if do_rebin:
            p = rebin(p,rebin_size)
            x = np.linspace(-det_x/2,det_x/2,rebin_size[0])
        plt.plot(x,np.mean(p,axis=0),'.-',ms=15,label=f'{pol_labels[indx]}')
    plt.ylabel('Pol')
    plt.xlabel('x (mm)')
    plt.legend()
    plt.show()
if plot_slices:
    x = np.linspace(-det_x/2,det_x/2,bin_x)
    for indx,p in enumerate(pols):
        fig = plt.figure(figsize=(plot_width,plot_height))
        if do_rebin:
            p = rebin(p,rebin_size)
            x = np.linspace(-det_x/2,det_x/2,rebin_size[0])
        plt.plot(x,np.mean(p,axis=0),'.-',ms=15,label=f'{pol_labels[indx]}',color=f'C{indx}')
        plt.ylabel('Pol')
        plt.xlabel('x (mm)')
        plt.legend()
        plt.show()
# Out:
# Currents used: [0.  1.  2.  2.8 3.  3.2 4.  5.  6. ]

# %%
print(currents)
start = 8*5
for indx in range(start,start+5):
    pol = np.mean((empty_cur_scan[2*indx]-empty_cur_scan[2*indx+1])/(empty_cur_scan[2*indx]+empty_cur_scan[2*indx+1]),axis=0)
    plt.plot(x,pol)
plt.show()
for indx in range(start,start+5):
    pol2 = np.mean((cur_scan[2*indx]-cur_scan[2*indx+1])/(cur_scan[2*indx]+cur_scan[2*indx+1]),axis=0)
    plt.plot(x,pol2,'--')
plt.show()

# %%
plt.imshow(cur_scan[0])
plt.colorbar()
plt.show()
plt.imshow(cur_scan[1])
plt.colorbar()
plt.show()
plt.imshow(temp:=(cur_scan[0]-cur_scan[1])/(cur_scan[0]+cur_scan[1]))
plt.colorbar()
plt.show()
plt.plot(np.mean(temp,axis=0))

# %% [markdown]
# ##### Complete Scan Analysis

# %%
def cos2(x,amp,per,phase):
    """Simple cosine with shim."""
    return amp*np.cos((x-x0)/per + phase)
x0 = CG_currents[0]
xd = 50

fig,ax = plt.subplots(figsize=(plot_width,plot_height))
x = np.linspace(-det_x/2,det_x/2,bin_x)
fine_currents = np.linspace(CG_currents[0],CG_currents[-1],200)
mins,maxs = [],[]

print(np.shape(empty_pols))

for n in range(5):
    centers,centers2 = [],[]
    for indx,(p,p2) in enumerate(zip(empty_pols[8*n:8*(n+1):],pols[8*n:8*(n+1):])):
        centers.append(np.mean(p[0:8:],axis=0)[xd])
        centers2.append(np.mean(p2[0:8:],axis=0)[xd])
    
    print(len(centers2))
    print(CG_currents)
    
    guess = [np.max(centers),.005,CG_currents[np.argmax(centers)]]
    lb = [0,guess[1]-.001,-1.5*np.pi]
    ub = [.75,guess[1]+.001,1.5*np.pi]
    bnds = (lb,ub)
    parms,_ = curve_fit(cos2,CG_currents,centers,p0=guess)#,bounds=bnds)
    #parms[2] = 0
    parms2,_ = curve_fit(cos2,CG_currents,centers2,p0=guess)#,bounds=bnds)
    #parms2[2] = 0
    subtracted = cos2(fine_currents,*parms2) - cos2(fine_currents,*parms)
    
    if True:
        #plt.plot(fine_currents,cos2(fine_currents,*guess),'--',color=f'C{n}')  #initial guess
        #plt.plot(CG_currents,centers,'.',ms=15,label=f'Empty {round(currents[n],2)}',color=f'C{n}')
        plt.plot(fine_currents,cos2(fine_currents,*parms),'-',color=f'C{n}')
        print(f'Empty: [amp,period,phase]={np.round(parms,5)}')
    if True:
        #plt.plot(fine_currents,cos2(fine_currents,*guess),'--',color=f'C{n}')  #initial guess
        #plt.plot(CG_currents,centers2,'.',ms=15,label=f'{round(currents[n],2)}',color=f'C{n}')
        plt.plot(fine_currents,cos2(fine_currents,*parms2),'-',color=f'C{n}')
        print(f'Sample: [amp,period,phase]={np.round(parms2,5)}')
    
    plt.plot(fine_currents,subtracted,'-',label=f'Sub {round(currents[n],2)}',color=f'C{n}',linewidth=4)
    
    maxs.append(fine_currents[np.argmax(np.abs(cos2(fine_currents,*parms)))])
    mins.append(fine_currents[np.argmin(np.abs(cos2(fine_currents,*parms)))])
plt.ylabel('Pol')
plt.xlabel('CG current (amps)')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

#print(np.round(maxs,5))
#print(np.round(mins,5))

# %% [markdown]
# ##### Empty beam analysis (daisy compatible)

# %%
empty_fine_currents = np.linspace(empty_currents[0],empty_currents[-1],200)
x = np.linspace(-res/2,res/2,200)
x_data = np.linspace(-det_x/2,det_x/2,bin_x)
x_data_fine = np.linspace(x_data[0],x_data[-1],200)

print(det_x/res)

A = CL*lam*strength*2*(L2-L1)/Ls*1e-3  #x is in mm
print(f'A = {round(A,5)}')
norml = 1/1.35  #(2*np.pi*A)
print(f'Normalization = {round(norml,5)}')

ignore_first = True
if ignore_first:
    empty_highs = np.array(empty_cur_scan[1::2])
    empty_lows = np.array(empty_cur_scan[2::2])
    empty_pols = [get_pol(empty_highs[i],empty_lows[i]) for i in range(0,(len(empty_cur_scan)-1)//2)]
else:
    empty_highs = np.array(empty_cur_scan[::2])
    empty_lows = np.array(empty_cur_scan[1::2])
    empty_pols = [get_pol(empty_highs[i],empty_lows[i]) for i in range(0,len(empty_cur_scan)//2)]
    
empty_slice_pos = [1.]  #P_B=1 at zero current
empty_all_currs = [np.ones(len(pols[0][0]))]
empty_slice_val = 0
empty_slice_indx = np.argmin(np.abs(x_data - empty_slice_val))
for p in empty_pols:
    empty_slice_pos.append(np.mean(p,axis=0)[empty_slice_indx])
    empty_all_currs.append(np.mean(p,axis=0))

empty_fitted_p = CubicSpline(empty_currents,empty_slice_pos)(empty_fine_currents)

plot_empty,plot_ana = True,False
if plot_empty:
    fig = plt.figure(figsize=(plot_width,plot_height/1.5))
    empty_ft_inv = []
    for xi in x+empty_slice_val:
        empty_ft_inv.append(1/norml*simpson(empty_fitted_p*\
                                            np.cos(A*empty_fine_currents*(xi-empty_slice_val)),\
                                            x=empty_fine_currents))
    plt.plot(x_data_fine,empty_ft_inv,linewidth=3,label='Recon.')
    plt.plot(x,np.ones(len(x)),'--',linewidth=3)
    plt.ylabel('Transmission')
    plt.xlabel('x (mm)')
    plt.legend()
    plt.show()

    fig = plt.figure(figsize=(plot_width,plot_height/1.5))
    plt.title('Pol slice')
    plt.plot(empty_currents,empty_slice_pos,'o',label=f'x={round(empty_slice_val,2)}')
    plt.plot(empty_fine_currents,empty_fitted_p,'--',linewidth=2,label='Spline')
    for c in get_SS_focus(harms,Ls,res,lam,MWP_parm['a'],L)[:6]:
        plt.axvline(x=c,linestyle='--',color='black',linewidth=2)
    plt.ylabel('Pol')
    plt.xlabel('MWP current')
    plt.legend()
    plt.show()

    fig = plt.figure(figsize=(plot_width,plot_height/1.5))
    plt.imshow(empty_all_currs,extent=[-det_x/2,det_x/2,empty_currents[0],empty_currents[-1]],origin='lower')
    for c in get_SS_focus(harms,Ls,res,lam,MWP_parm['a'],L)[:6]:
        plt.axhline(y=c,linestyle='--',color='black',linewidth=2)
    plt.ylabel('MWP current')
    plt.xlabel('x (mm)')
    plt.colorbar()
    plt.show()
    
    if True:
        x = np.linspace(-det_x/2,det_x/2,bin_x)
        for indx,p in enumerate(empty_pols):
            fig = plt.figure(figsize=(plot_width,plot_height))
            plt.plot(x,np.mean(p,axis=0),'.-',ms=15,label=f'{pol_labels[indx]}',color=f'C{indx}')
            plt.ylabel('Pol')
            plt.xlabel('x (mm)')
            plt.legend()
            plt.show()

if plot_ana:
    fig = plt.figure(figsize=(plot_width,plot_height/1.5))
    plt.title('Analytical soln')
    analytic_pol = [np.sinc(A*i*res/2/np.pi)*np.cos(A*i*x_data*Ls/Ld) for i in empty_fine_currents]
    plt.imshow(analytic_pol,extent=[-det_x/2,det_x/2,empty_currents[0],empty_currents[-1]],origin='lower')
    for c in get_SS_focus(harms,Ls,res,lam,MWP_parm['a'],L)[:6]:
        plt.axhline(y=c,linestyle='--',color='black',linewidth=2)
    plt.ylabel('MWP current')
    plt.xlabel('x (mm)')
    plt.colorbar()
    plt.show()
# Out:
# 8.851851851851851
# A = 0.64423
# Normalization = 0.74074

# %% [markdown]
# ##### Daisy scan analysis

# %%
fine_currents = np.linspace(currents[0],currents[-1],200)
x = np.linspace(-res/2,res/2,200)
x_data = np.linspace(-det_x/2,det_x/2,bin_x)

A = CL*lam*strength*2*(L2-L1)/Ls*1e-3  #x is in mm
print(f'A = {round(A,5)}')
norml = 2*np.pi*A
print(f'Normalization = {round(norml,5)}')

slice_pos = [1.]  #P_B=1 at zero current
all_currs = [np.ones(len(pols[0][0]))]
slice_val = 0.
slice_indx = np.argmin(np.abs(x_data - slice_val))

x_fine = np.linspace(-slit_inner/2,slit_inner/2,400,endpoint=True)
MASK = grating(x_fine,slit_width,slit_width,slit_num,slit_offset)
SEEN,x_min,x_max = seen_grating(x_fine,MASK,slice_val,Ls,Ld,Ls*ap_width/Ld)
seen_x = np.linspace(x_min,x_max,len(x))
print(np.round([x_min,x_max],3))

for p in pols:
    slice_pos.append(np.mean(p,axis=0)[slice_indx])
    all_currs.append(np.mean(p,axis=0))

fitted_p = CubicSpline(currents,slice_pos)(fine_currents)

plot_sample = True
if plot_sample:
    fig = plt.figure(figsize=(plot_width,plot_height/1.5))
    ft_inv = []
    for xi in seen_x:
        ft_inv.append(1/norml*simpson(fitted_p*np.cos(A*fine_currents*(xi-slice_val)),fine_currents))
    plt.plot(seen_x,ft_inv,linewidth=3,label='Recon.')
    plt.plot(x_fine,SEEN,'--',linewidth=3,label='Seen grating')
    plt.legend()
    plt.ylabel('Transmission')
    plt.xlabel('x (mm)')
    plt.show()

    fig = plt.figure(figsize=(plot_width,plot_height/1.5))
    plt.title('Pol slice')
    plt.plot(currents,slice_pos,'o',ms=5,label=f'x={round(slice_val,2)}')
    plt.plot(fine_currents, fitted_p,'--',linewidth=2,label='Spline')
    for c in get_SS_focus(harms,Ls,res,lam,MWP_parm['a'],L)[:6]:
        plt.axvline(x=c,linestyle='--',color='black',linewidth=2)
    plt.ylabel('Pol')
    plt.xlabel('MWP current')
    plt.legend()
    plt.show()

    analytic_pol = np.array([np.sinc(A*i*res/2/np.pi)*np.cos(A*i*x_data*Ls/Ld) for i in currents])
    all_currs_normed = all_currs - analytic_pol
    
    fig = plt.figure(figsize=(plot_width,plot_height/1.5))
    plt.imshow(all_currs,extent=[-det_x/2,det_x/2,currents[0],currents[-1]],origin='lower',vmax=1)
    for c in get_SS_focus(harms,Ls,res,lam,MWP_parm['a'],L)[:6]:
        plt.axhline(y=c,linestyle='--',color='black',linewidth=2)
    plt.ylabel('MWP current')
    plt.xlabel('x (mm)')
    plt.colorbar()
    plt.show()
# Out:
# A = 0.64423
# Normalization = 4.04784
# Lower/upper limits: -2.182,2.182
# [ 2.182 -2.182]

# %% [markdown]
# ### Comparison:

# %%
fig = plt.figure(figsize=(plot_width,plot_height/1.5))
plt.title(f'Pol at x={slice_val}')
plt.plot(fine_currents,fitted_p,'--',label='Sample',linewidth=3)
plt.plot(empty_fine_currents,empty_fitted_p,'--',label='Empty',linewidth=3)
if len(empty_fine_currents)==len(fine_currents):
    subtracted = fitted_p - empty_fitted_p
    plt.plot(fine_currents,subtracted,label='Subtracted',linewidth=3)
    pks,_ = find_peaks(subtracted,height=.05)
    trs,_ = find_peaks(-subtracted,height=.05)
    print(f'Peaks found: {np.round(fine_currents[pks],3)} amp')
    print(f'\t {np.round(2*np.pi/A/fine_currents[pks],3)} mm')
    print(f'\t Peak values: {np.round(fitted_p[pks],3)}')
    print(f'Troughs found: {np.round(fine_currents[trs],3)} amp')
    print(f'\t {np.round(2*np.pi/A/fine_currents[trs],3)} mm')
    print(f'\t Trough values: {np.round(fitted_p[trs],3)}')
for c in get_SS_focus(harms,Ls,res,lam,MWP_parm['a'],L)[:6]:
    plt.axvline(x=c,linestyle='--',color='black',linewidth=2)
plt.ylabel('Pol')
plt.xlabel('MWP current')
plt.legend()
plt.show()
# Out:
# Peaks found: [3.256] amp
# 	 [2.995] mm
# 	 Peak values: [0.396]
# Troughs found: [] amp
# 	 [] mm
# 	 Trough values: []

# %%
print(c1)
# Out:
# [0.         2.97695718 5.95391437 8.93087155]

# %% [markdown]
# ##### Center guide field scan analysis

# %%
def cg_cos(x,a,per,p):
    return a*np.cos(x*2*np.pi/per + p)
fine_currents = np.linspace(currents[1],currents[-1],200)

centers = []
for indx,p in enumerate(pols):
    centers.append(np.mean(p,axis=0)[50])
lwb, upb = [.3,0,-3.14], [.7,.05,3.14]
parms,_ = curve_fit(cg_cos,currents[1:],centers,p0=[.5,.033,0],bounds=[lwb,upb])
print(f'[amp,per,phase]: {np.round(parms,5)}')
    
plt.title('Pol at x=0')
plt.plot(currents[1:],centers,'o')
plt.plot(fine_currents,cg_cos(fine_currents,*parms))
plt.ylabel('Pol')
plt.xlabel('Center guide current')
plt.show()

# %% [markdown]
# Polarization seems to take a hit even with the low wavelegth spread of CG-4B when we turn on the guide field. Hopefully this can be corrected/accounted for for the reconstruction.

# %% [markdown]
# ### Normed Intensity Extractor (to fix)

# %%
def get_ni(data,zeroth):
    """Returns 2D N_0 normalized intensity from current scans."""
    nint = np.zeros(np.shape(data[0]))
    for indx,val in np.ndenumerate(nint):
        if zeroth[indx[0],indx[1]] != 0:
            nint[indx[0],indx[1]] = data[0,indx[0],indx[1]]/zeroth[indx[0],indx[1]]
    return nint
nints = [get_ni(np.array(cur_scan[i]),np.array(cur_scan[0])) for i in range(1,len(cur_scan)//2-1,2)]
print(f'Currents used: {np.round(currents,2)} \n')

plot_nints,plot_slices,plot_all_slices = False,True,True

do_rebin = False
rebin_size = (50,50)
if do_rebin: print(f'New bin size: {round(det_x/rebin_size[0],3)} (mm)')

if plot_nints:
    for indx,n in enumerate(nints):
        fig = plt.figure(figsize=(plot_width,plot_height))
        plt.title(f'Harm. {indx+1}, {round(currents[indx+1],2)} amps')
        plt.tight_layout()
        if do_rebin: n=rebin(p,rebin_size)
        plt.imshow(n,origin='lower',extent=[-det_x/2,det_x/2,-det_y/2,det_y/2],interpolation='none')
        plt.ylabel('y (mm)')
        plt.xlabel('x (mm)')
        plt.colorbar()
        plt.show()

if plot_all_slices:
    fig = plt.figure(figsize=(plot_width,plot_height))
    x = np.linspace(-det_x/2,det_x/2,bin_x)
    for indx,n in enumerate(nints):
        if do_rebin:
            n = rebin(n,rebin_size)
            x = np.linspace(-det_x/2,det_x/2,rebin_size[0])
        plt.plot(x,np.mean(n,axis=0),'.-',ms=15,label=f'{round(currents[indx+1],2)}')
    plt.ylabel('Norm I')
    plt.xlabel('x (mm)')
    plt.legend()
    plt.show()

if plot_slices:
    x = np.linspace(-det_x/2,det_x/2,bin_x)
    for indx,n in enumerate(nints):
        fig = plt.figure(figsize=(plot_width,plot_height))
        if do_rebin:
            n = rebin(n,rebin_size)
            x = np.linspace(-det_x/2,det_x/2,rebin_size[0])
        plt.plot(x,np.mean(n,axis=0),'.-',ms=15,label=f'{round(currents[indx+1],2)},{indx+1}',color=f'C{indx}')
        envelope = np.mean(n,axis=0)/np.abs(hilbert(np.mean(n,axis=0)))
        #plt.plot(x,envelope,'--',color=f'C{indx}')
        #plt.plot(x,-envelope,'--',color=f'C{indx}')
        plt.ylabel('Norm I')
        plt.xlabel('x (mm)')
        plt.legend()
        plt.show()

# %% [markdown]
# ***
# ## Analytical and Simulated Reconstruction Comparison
# ***

# %%
x = np.linspace(-det_x/2,det_x/2,bin_x)
x_mid = x[len(p)//2-4:len(p)//2+4]
x_fine = np.linspace(-det_x/2,det_x/2,200)
fits,errs,guess = [[] for i in range(len(pols))],[[] for i in range(len(pols))],[[] for i in range(len(pols))]
peak_fits,peak_errs,peak_guess = [[] for i in range(len(pols))],[[] for i in range(len(pols))],[[] for i in range(len(pols))]

def fit_pols(pols,plot_fits=True,plot_peaks=True):
    for i,_ in enumerate(pols):
        p = np.mean(pols[i],axis=0)
        guess[i] = np.array([p[len(p)//2],.0,2*np.pi*(i + 1)/res])
        #guess[i] = np.array([p[len(p)//2],2*np.pi*(i + 2)/res,0])
        peak_guess[i] = [-1.,0,p[len(p)//2]]
        p_mid = p[len(p)//2-4:len(p)//2+4]
        fits[i],errs[i] = curve_fit(pol_sc,x,p,p0=guess[i])
        peak_fits[i],peak_errs[i] = curve_fit(quad,x_mid,p_mid,p0=guess[i])
        
        if plot_fits:
            fig = plt.figure(figsize=(plot_width,plot_height))
            plt.title(f'Harm. {i+1}, {round(currents[i+1],2)} amps')
            plt.plot(x,np.mean(pols[i],axis=0),'.',color='C0')
            plt.plot(x,pol_sc(x,*fits[i]),color='C0',label='Fit')
            plt.plot(x,pol_sc(x,*guess[i]),color='C1',label='Guess')
            plt.legend()
            plt.show()
        if plot_peaks:
            fig = plt.figure(figsize=(plot_width,plot_height))
            plt.title(f'Harm. {i+1}, {round(currents[i+1],2)} amps')
            plt.plot(x,np.mean(pols[i],axis=0),'.',color='C0')
            plt.plot(x_mid,quad(x_mid,*peak_fits[i]),color='C0',label='Quad Fit')
            print(f'Const={round(peak_fits[i][2],2)}, Lin={round(peak_fits[i][1],2)}')
            plt.legend()
            plt.show()

def sum_series(x,R,an,bn,nl,nu,a0=1,norm=True):
    """Sums Fourier series from coefficients."""
    assert(len(an) == len(bn)), "Too many an's or bn's!"
    cn = np.array([np.cos(2*np.pi*(i+1)*x/R) for i in range(nl,nu)])
    sn = np.array([np.sin(2*np.pi*(i+1)*x/R) for i in range(nl,nu)])
    tot = a0 + 2*(np.dot(an,cn) + np.dot(bn,sn))
    if norm: tot = tot/simpson(tot,x) #divide by resolution, because a0 = 1/res
    return tot

def get_coeff(x,f,n,R,print_coeff=True):
    """Returns Fourier cosine or sine coefficient."""
    an = simpson(f*np.cos(2*np.pi*n/R*x),x)
    bn = simpson(f*np.sin(2*np.pi*n/R*x),x)
    if print_coeff: print(f'\t a{n} = {round(an,5)}, b{n} = {round(bn,5)}')
    return an,bn

def get_ana(x,f,nl,nu,R,a0=1,norm=True,print_coeff=False):
    """Returns Fourier series up to order n. a0 is given."""
    an,bn = np.zeros(nu-nl),np.zeros(nu-nl)
    if print_coeff: print(f'Analytic Fourier coefficients:')
    for indx,n in enumerate(range(nl,nu)):
        an[indx],bn[indx] = get_coeff(x,f,n+1,R,print_coeff=print_coeff)
    return sum_series(x,R,an,bn,nl,nu,a0=a0,norm=norm), an, bn

def get_N0(x,f,R,norm=True):
    """Returns traditional normalized radiograph (n=0)."""
    return 1/res*simpson(f,x)
    
fit_pols(pols,plot_fits=False,plot_peaks=False)
peak_fits = np.array(peak_fits)
print('Simulated Fourier coefficients:')
for n in range(len(peak_fits[:,2])):
    print(f'\t a{n+1} = {round(peak_fits[n,2],5)}, b{n+1} = {round(peak_fits[n,1],5)}')
    
res_fine = np.linspace(-res/2,res/2,200)

coarse_mask = grating(res_fine,2,2,5,.75)  #magic number for offset
coarse_mask = coarse_mask/simpson(coarse_mask,res_fine)

images = [sum_series(res_fine,res,peak_fits[:i,2],peak_fits[:i,1],0,i) for i in harms[1:]]
anas = [get_ana(res_fine,coarse_mask,0,i,res)[0] for i in harms[1:-1]] + \
        [get_ana(res_fine,coarse_mask,0,harms[-1],res)[0]]
ana_coeffs = get_ana(res_fine,coarse_mask,0,len(harms)-1,res,print_coeff=True)[1:]

N0 = np.mean(cur_scan[0],axis=0)/simpson(np.mean(cur_scan[0],axis=0),x)

plot_ps,plot_comps = True,False

for i in harms[:-1]:
    if plot_ps:
        fig = plt.figure(figsize=(plot_width,plot_height))
        plt.title(f'Sum up to harmonic {i+1}')
        plt.plot(res_fine,images[i],linewidth=4,label='Simulated')
        plt.plot(res_fine,anas[i],linewidth=4,label='Analytic')
        plt.plot(res_fine,coarse_mask,linewidth=4,label='T(x)')
        plt.plot(x,N0,linewidth=4,label='N_0')
        plt.legend()
        plt.show()
    
    if plot_comps:
        fig = plt.figure(figsize=(plot_width,plot_height))
        plt.title(f'Only harmonic {i+1}')
        temp_sim = sum_series(res_fine,res,[peak_fits[i,2]],[peak_fits[i,1]],i,i+1)
        temp_ana = get_ana(res_fine,coarse_mask,i,i+1,res)[0]
        plt.plot(res_fine,temp_sim,linewidth=4,label='Simulated')
        plt.plot(res_fine,temp_ana,linewidth=4,label='Analytic')
        plt.plot(res_fine,coarse_mask,linewidth=4,label='T(x)')
        plt.plot(x,N0,linewidth=4,label='N_0')
        plt.legend()
        plt.show()

# %%
CL*lam*strength*2*.3*1e-3

# %%
6.28/(CL*lam*strength*2*.4*1e-3)

# %%
12.58/3.9*1.9

# %%
len(np.arange(1,10,.3))

# %%
def AER_ani(frame):
    frame += 2
    temp_cos_vals_num = 2*np.array([simple_cos(xpos_finer, *nic_hc_fits[i])[500] for i in range(0,frame)]) - 1
    temp_cos_vals_num = np.insert(temp_cos_vals_num, 0, 1/2, axis=0)
    temp_recon_num = np.asarray([temp_cos_vals_num[0] + np.sum(np.array([temp_cos_vals_num[i]*np.cos(2*np.pi*i/res*x) \
                                for i in range(1,frame)]), axis=0) for x in xpos_finer])
    temp_recon_num = temp_recon_num/np.sum(temp_recon_num)
    ax.set_title(r'Reconstruction up to $N ='+str(frame-1)+'$')
    line.set_ydata(temp_recon_num)
    line.set_label(r'$N=$'+str(frame-1))
    plt.text(-1.6, 5e-3, r'$R_{\mathrm{AER}}=\num{'+str(round(res/frame,2))+r'}\unit{\milli \meter}$', \
             fontdict=dict(fontsize=60), bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=.25'))
    plt.legend()
    
fig = plt.figure(figsize=(plot_width,plot_height))
ax = plt.axes()
ax.plot(xpos_finer, slit_T(xpos_finer, slit_x*1e-3)/np.sum(slit_T(xpos_finer, slit_x*1e-3)), linewidth=8, label='$T(x)$')
line, = ax.plot(xpos_finer, np.zeros(len(xpos_finer)), linewidth=8)
#ax.plot(xpos_finer, np.zeros(len(xpos_finer)), '-', linewidth=5, label='Num. Recon')
#plt.plot(xpos_finer, recon_num/np.sum(recon_num), '--', linewidth=5, label='Num. Recon')
#plt.text(-1.6, 7.75e-3, r'Slit width = $\num{200}\unit{\micro \meter}$', \
#         bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=.25'))
ax.set_ylim(-.002, .010)
plt.xlabel('x ' + r'$[\unit{\milli \meter}]$')
plt.ylabel('Transmission')
plt.legend()
plt.grid('on')

F_tot = 6
F_int = 200
FPS = .5
anim = FuncAnimation(fig, AER_ani, frames=F_tot, interval=F_int, repeat=False)
anim.save('Aer_soln_FPS'+str(FPS)+'_frames'+str(F_tot)+'.gif', writer='pillow', fps=FPS)
plt.close()
print('Ding!')

# %%
def AER_ani(frame):
    frame += 7
    temp_cos_vals_num = 2*np.array([simple_cos(xpos_finer, *nic_hc_fits[i])[500] for i in range(0,frame)]) - 1
    temp_cos_vals_num = np.insert(temp_cos_vals_num, 0, 1/2, axis=0)
    temp_recon_num = np.asarray([temp_cos_vals_num[0] + np.sum(np.array([temp_cos_vals_num[i]*np.cos(2*np.pi*i/res*x) \
                                for i in range(1,frame)]), axis=0) for x in xpos_finer])
    temp_recon_num = temp_recon_num/np.sum(temp_recon_num)
    ax.set_title(r'Reconstruction up to $N ='+str(frame-1)+'$')
    line.set_ydata(temp_recon_num)
    line.set_label(r'$N=$'+str(frame-1))
    plt.text(-1.6, 5e-3, r'$R_{\mathrm{AER}}=\num{'+f"{round(res/frame,2):.2f}"+r'}\unit{\milli \meter}$', \
             fontdict=dict(fontsize=60), bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=.25'))
    plt.legend()
    
fig = plt.figure(figsize=(plot_width,plot_height))
ax = plt.axes()
ax.plot(xpos_finer, slit_T(xpos_finer, slit_x*1e-3)/np.sum(slit_T(xpos_finer, slit_x*1e-3)), linewidth=8, label='$T(x)$')
line, = ax.plot(xpos_finer, np.zeros(len(xpos_finer)), linewidth=8)
#ax.plot(xpos_finer, np.zeros(len(xpos_finer)), '-', linewidth=5, label='Num. Recon')
#plt.plot(xpos_finer, recon_num/np.sum(recon_num), '--', linewidth=5, label='Num. Recon')
#plt.text(-1.6, 7.75e-3, r'Slit width = $\num{200}\unit{\micro \meter}$', \
#         bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=.25'))
ax.set_ylim(-.002, .011)
plt.xlabel('x ' + r'$[\unit{\milli \meter}]$')
plt.ylabel('Transmission')
plt.legend()
plt.grid('on')

F_tot = 10
F_int = 200
FPS = .5
anim = FuncAnimation(fig, AER_ani, frames=F_tot, interval=F_int, repeat=False)
anim.save('Aer_soln_higher_FPS'+str(FPS)+'_frames'+str(F_tot)+'.gif', writer='pillow', fps=FPS)
plt.close()
print('Ding!')

# %%
acc_zero_sam = [run/np.max(run) for run in acc_zero_sam]
acc_zero_empty = [run/np.max(run) for run in acc_zero_empty]
acc_sam = [run/np.max(run) for run in acc_sam]
acc_empty = [run/np.max(run) for run in acc_empty]

run_list = [acc_zero_empty,acc_zero_sam,acc_empty,acc_sam]
titles = ['Source','Pre-sample','Post-sample','Detector']

for run in run_list:
    fig,axs = plt.subplots(2,2,figsize=(12,12))
    #fig.suptitle('Acceptance Diagrams')
    axs[0,0].set_title(titles[0],size=30)
    im = axs[0,0].imshow(run[-4],extent=[-det_x/2,det_x/2,-max_div,max_div],origin='lower',\
                    aspect=20,vmin=0,vmax=1,cmap='GnBu')
    axs[0,1].set_title(titles[1],size=30)
    axs[0,1].imshow(run[-3],extent=[-det_x/2,det_x/2,-max_div,max_div],origin='lower',\
                    aspect=20,vmin=0,vmax=1,cmap='GnBu')
    axs[1,0].set_title(titles[2],size=30)
    axs[1,0].imshow(run[-2],extent=[-det_x/2,det_x/2,-max_div,max_div],origin='lower',\
                   aspect=20,vmin=0,vmax=1,cmap='GnBu')
    axs[1,1].set_title(titles[3],size=30)
    axs[1,1].imshow(run[-1],extent=[-det_x/2,det_x/2,-max_div,max_div],origin='lower',\
                   aspect=20,vmin=0,vmax=1,cmap='GnBu')
    fig.supylabel(r'$\phi$ (deg)',size=35)
    fig.supxlabel(r'$x$ (mm)',size=35)
    cbar_ax = fig.add_axes([0.925, 0.35, 0.015, 0.3])    #left, bottom, width, height
    fig.colorbar(im, cax=cbar_ax, aspect=1)
    #plt.tight_layout()
    plt.show()
